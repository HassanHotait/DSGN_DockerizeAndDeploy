# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('/home/DSGN_DockerizeAndDeploy/data/DrivingStereoSet/training/image_2/000587.png')
plt.imshow(img[:,:,::-1])

# %%
depth_pred = np.load('/home/DSGN_DockerizeAndDeploy/outputs/result/depth_maps/000587_disparity.npy')
print(f'depth shape: {depth_pred.shape}')
plt.imshow(depth_pred,cmap = 'jet')
print(f'min depth: {np.min(depth_pred)}')
print(f'max depth: {np.max(depth_pred)}')
# Out:
# depth shape: (384, 881)
# min depth: 2.00011944770813
# max depth: 40.188148498535156

# %%
print(f'min depth: {np.min(depth_pred)}')
print(f'max depth: {np.max(depth_pred)}')
# Out:
# min depth: 2.00011944770813
# max depth: 40.188148498535156

# %%
depth_gt = cv2.imread('/home/DSGN_DockerizeAndDeploy/data/DrivingStereoSet/training/depth/000587.png',cv2.IMREAD_GRAYSCALE)
depth_gt_norm = cv2.normalize(depth_gt, None, 2, 40, cv2.NORM_MINMAX)
np.save('/home/DSGN_DockerizeAndDeploy/data/DrivingStereoSet/training/depth/000587.npy',depth_gt_norm)
# print(f'depth shape: {depth_gt.shape}')
plt.imshow(depth_gt,cmap = 'jet')

print(f'min depth: {np.min(depth_gt)}')
print(f'max depth: {np.max(depth_gt)}')
# Out:
# min depth: 0
# max depth: 111

# %%
disparity_gt = cv2.imread('/home/DSGN_DockerizeAndDeploy/data/DrivingStereoSet/training/disparity/000587.png',cv2.IMREAD_GRAYSCALE)
np.save('/home/DSGN_DockerizeAndDeploy/data/DrivingStereoSet/training/disparity/000587.npy',disparity_gt)
# disparity_gt_norm = cv2.normalize(disparity_gt, None, 2, 40, cv2.NORM_MINMAX)
print(f'disparity shape: {disparity_gt.shape}')
plt.imshow(disparity_gt,cmap = 'jet')

print(f'min disparity: {np.min(disparity_gt)}')
print(f'max disparity: {np.max(disparity_gt)}')
# Out:
# disparity shape: (400, 881)
# min disparity: 0
# max disparity: 70

# %%
depth_pred_kitti = np.load('/home/DSGN_DockerizeAndDeploy/data/kitti/training/depth/000000.npy')
print(f'depth shape: {depth_pred_kitti.shape}')
plt.imshow(depth_pred_kitti,cmap = 'jet')

print(f'min depth: {np.min(depth_pred_kitti)}')
print(f'max depth: {np.max(depth_pred_kitti)}')
# Out:
# depth shape: (370, 1224)
# min depth: -1.0
# max depth: 72.72496954215289
